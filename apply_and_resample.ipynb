# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsha84/DS_projects/blob/main/apply_and_resample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
sin=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')
sin.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
sin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
sin.Year=pd.to_datetime(sin.Year,format='%Y')    # converting to date format
sin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %%
sin.head()
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
sin=sin.set_index('Year')
sin.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
del sin['Total']
sin.head()
# Out:
#             Population  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960-01-01   179323175   288460   3095700    9110          17190   107840
# 1961-01-01   182992000   289390   3198600    8740          17220   106670
# 1962-01-01   185771000   301510   3450700    8530          17550   110860
# 1963-01-01   188483000   316970   3792500    8640          17650   116470
# 1964-01-01   191141000   364220   4200400    9360          21420   130390
#
#             Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960-01-01              154320    912100        1855400         328200
# 1961-01-01              156760    949600        1913000         336000
# 1962-01-01              164570    994300        2089600         366800
# 1963-01-01              174210   1086400        2297800         408300
# 1964-01-01              203050   1213200        2514400         472800

# %%
sins=sin.resample('10AS').sum()   # converting to decade form
sins
# Out:
#             Population   Violent   Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960-01-01  1915053175   4134930   45160900  106180         236720  1633510
# 1970-01-01  2121193298   9607930   91383800  192230         554570  4159020
# 1980-01-01  2371370069  14074328  117048900  206439         865639  5383109
# 1990-01-01  2612825258  17527048  119053499  211664         998827  5748930
# 2000-01-01  2947969117  13968056  100944369  163068         922499  4230366
# 2010-01-01  1570146307   6072017   44095950   72867         421059  1749809
#
#             Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960-01-01             2158520  13321100       26547700        5292100
# 1970-01-01             4702120  28486000       53157800        9739900
# 1980-01-01             7619130  33073494       72040253       11935411
# 1990-01-01            10568963  26750015       77679366       14624418
# ...

# %%
sins1=sin.resample('10AS').sum()
pop=sins1['Population'].resample('10AS').max()
Population=pop
sins1
# Out:
#             Population   Violent   Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960-01-01  1915053175   4134930   45160900  106180         236720  1633510
# 1970-01-01  2121193298   9607930   91383800  192230         554570  4159020
# 1980-01-01  2371370069  14074328  117048900  206439         865639  5383109
# 1990-01-01  2612825258  17527048  119053499  211664         998827  5748930
# 2000-01-01  2947969117  13968056  100944369  163068         922499  4230366
# 2010-01-01  1570146307   6072017   44095950   72867         421059  1749809
#
#             Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960-01-01             2158520  13321100       26547700        5292100
# 1970-01-01             4702120  28486000       53157800        9739900
# 1980-01-01             7619130  33073494       72040253       11935411
# 1990-01-01            10568963  26750015       77679366       14624418
# ...

# %%
sins.idxmax(0)
# Out:
# Population           2000-01-01
# Violent              1990-01-01
# Property             1990-01-01
# Murder               1990-01-01
# Forcible_Rape        1990-01-01
# Robbery              1990-01-01
# Aggravated_assault   1990-01-01
# Burglary             1980-01-01
# Larceny_Theft        1990-01-01
# Vehicle_Theft        1990-01-01
# dtype: datetime64[ns]

# %%
 # creating a time series-exercise-not relevant to 'sin' data
 time=pd.date_range('24-8-1984',periods=10,freq='T')
 series=pd.Series(range(10),index=time)
 series
# Out:
# 1984-08-24 00:00:00    0
# 1984-08-24 00:01:00    1
# 1984-08-24 00:02:00    2
# 1984-08-24 00:03:00    3
# 1984-08-24 00:04:00    4
# 1984-08-24 00:05:00    5
# 1984-08-24 00:06:00    6
# 1984-08-24 00:07:00    7
# 1984-08-24 00:08:00    8
# 1984-08-24 00:09:00    9
# Freq: T, dtype: int64

# %%
series.resample('5T').sum()
# Out:
# 1984-08-24 00:00:00    10
# 1984-08-24 00:05:00    35
# Freq: 5T, dtype: int64

# %%
d = {'price': [10, 11, 9, 13, 14, 18, 17, 19],
     'volume': [50, 60, 40, 100, 50, 100, 40, 50]}
df=pd.DataFrame(d)
df
# Out:
#    price  volume
# 0     10      50
# 1     11      60
# 2      9      40
# 3     13     100
# 4     14      50
# 5     18     100
# 6     17      40
# 7     19      50

# %%
df['week_start']=pd.date_range('1/1/2022', periods=8, freq='W')
df
# Out:
#    price  volume week_start
# 0     10      50 2022-01-02
# 1     11      60 2022-01-09
# 2      9      40 2022-01-16
# 3     13     100 2022-01-23
# 4     14      50 2022-01-30
# 5     18     100 2022-02-06
# 6     17      40 2022-02-13
# 7     19      50 2022-02-20
